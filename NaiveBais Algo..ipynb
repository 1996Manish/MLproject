# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import tree
import seaborn as sns

# %%
data=pd.read_csv('adult.data',header=None)
(data.head())
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
data.columns=['age','workclass','fnlwgt','education','education','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','income']

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.size
# Out:
# 488415

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education         32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
#                  age        fnlwgt  education     education  capital-gain  \
# count   32561.000000  3.256100e+04      32561  32561.000000  32561.000000
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data['age'].count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                 Total  Percent
# income              0      0.0
# native-country      0      0.0
# hours-per-week      0      0.0
# capital-loss        0      0.0
# capital-gain        0      0.0

# %%
columns=['workclass','occupation','native-country']
print(sum(data['workclass']==' ?'))
for col in columns:
    data[col].replace([' ?'],[data.describe(include='all')[col][2]],inplace=True)
# Out:
# 1836

# %%
columns=['workclass','occupation','native-country']
sum(data['workclass']==' ?')
# Out:
# 1836

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
workclass_tran=le.fit_transform(data.workclass)
data['workclass']=workclass_tran
data.describe(include='all')
# Out:
#                  age     workclass        fnlwgt  education     education  \
# count   32561.000000  32561.000000  3.256100e+04      32561  32561.000000
# unique           NaN           NaN           NaN         16           NaN
# top              NaN           NaN           NaN    HS-grad           NaN
# freq             NaN           NaN           NaN      10501           NaN
# mean       38.581647      3.868892  1.897784e+05        NaN     10.080679
# std        13.640433      1.455960  1.055500e+05        NaN      2.572720
# min        17.000000      0.000000  1.228500e+04        NaN      1.000000
# 25%        28.000000      4.000000  1.178270e+05        NaN      9.000000
# 50%        37.000000      4.000000  1.783560e+05        NaN     10.000000
# 75%        48.000000      4.000000  2.370510e+05        NaN     12.000000
# max        90.000000      8.000000  1.484705e+06        NaN     16.000000
#
#              marital-status       occupation relationship    race    sex  \
# ...
